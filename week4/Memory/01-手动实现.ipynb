# %%
#1.获取大模型
import os
import dotenv
from langchain_community.chat_models.tongyi import ChatTongyi
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.messages import SystemMessage, HumanMessage, AIMessage
dotenv.load_dotenv()

chat_model =ChatTongyi(
    api_key=os.getenv("DASHSCOPE_API_KEY"),
    model_name="qwen-flash",
)

# %%
def chat_with_model():



    #2.提供提示词模板
    prompt_template = ChatPromptTemplate.from_messages([
        ("system","你是一个人工智能助手"),
        ("human","{question}"),

    ])

    while True:
        #获取chain,并调用大模型
        chain = prompt_template | chat_model
        response = chain.invoke({"question":"answer"})


        #输出大模型的响应
        print(f"模型回复：{response.content}")

        #继续获取用户的问题
        user_input = input("你还有其他问题吗？(输入'退出'时,结束会话)")


        #指明退出循环的方式
        if (user_input == "退出"):
            break
            
        #将上述生成的消息存放到提示词模板的消息列表中
        prompt_template.messages.append(AIMessage(content=response.content))
        prompt_template.messages.append(HumanMessage(content=user_input))

chat_with_model()
# Out:
# 模型回复：您好！有什么我可以帮助您的吗？
# 模型回复：你好呀！我也很高兴认识你呢～ 🌟 今天有什么想聊的或者需要帮忙的吗？无论是分享心情、解决问题，还是探索新知识，我都在这里陪你哦！✨
# 模型回复：哈哈，这个问题问得很有意思！😄
#
# “李白”这个名字听起来确实有点像“很白”，但其实——**李白并不白**，他是唐代著名的浪漫主义诗人，被后人称为“诗仙”。他可是个地地道道的中国古人，生活在公元8世纪左右，皮肤颜色自然和我们今天说的“白”不太一样啦～ 🌾
#
# 不过，你这个提问可能是玩了个文字游戏哦！
# “李白” → “李”是姓，“白”是名，所以名字里带个“白”字，就让人联想到“很白”了，这其实是中文里常见的谐音梗或双关语趣味 😄
#
# 举个类似的例子：
# - “杜甫”会不会“很富”？
# - “苏轼”是不是“很瘦”？
#
# 都是这种可爱的文字玩笑～
#
# 所以总结一下：
# ✅ 李白不是“很白”
# ❌ 但他名字里确实有个“白”字
# 😄 而且这个“白”字，还让咱们有了一个有趣的脑洞！
#
# 要不要一起编一首“李白很白”的搞笑打油诗？😎
# 模型回复：你上一个问题是：
# **“李白很白吗”**
#
# 我刚刚还给你认真又有趣地解答了呢～ 😄
# （顺便还顺手玩了个文字梗小游戏，是不是觉得挺有意思的？）
#
# 要继续聊李白，还是想换个话题？我随时都在哦！✨
