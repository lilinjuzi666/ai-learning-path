# %%
#例1.从物理磁盘的yaml文件中读取prompt数据

from langchain_core.prompts import load_prompt
from dotenv import load_dotenv

# 加载环境变量（如 API Key）
load_dotenv()

# 从物理磁盘加载 YAML 格式的 prompt 模板
prompt = load_prompt("prompt.yaml", encoding="utf-8")

# print(prompt)
# 格式化并打印结果
print(prompt.format(name="年轻人", what="滑稽"))
# Out:
# 请给年轻人讲一个关于滑稽的故事
# C:\Users\tongnan\AppData\Local\Temp\ipykernel_11272\1186854269.py:10: LangChainDeprecationWarning: The function `load_prompt` was deprecated in LangChain 1.2.21 and will be removed in 2.0.0. Use `Use `dumpd`/`dumps` from `langchain_core.load` to serialize prompts and `load`/`loads` to deserialize them.` instead.
#   prompt = load_prompt("prompt.yaml", encoding="utf-8")

# %%
#2.从json中读取
from langchain_core.prompts import load_prompt
from dotenv import load_dotenv

# 加载环境变量
load_dotenv()

# 从 asset 文件夹加载 json 格式的 prompt 模板
prompt = load_prompt("prompt.json", encoding="utf-8")

# 格式化模板并打印结果
print(prompt.format(name="张三", what="搞笑的"))
# Out:
# 请张三讲一个搞笑的的故事。
