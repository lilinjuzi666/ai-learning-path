# %%
import os
from client import get_completion
from IPython.display import display,Markdown

# %%
text=f"""
写两篇文章，100字以内
"""
prompt=f"""
example1:独有叫喊于生人中，而生人并无反应，既非赞同，也无反对，如置身毫无边际的荒原，无可措手的了，这是怎样的悲哀。
example2:然而我虽然自有无端的悲哀，却也并不愤懑，因为这经验使我反省，看见自己了：就是我决不是一个振臂一呼应者云集的英雄。
example3:我想：希望本是无所谓有，无所谓无的。这正如地上的路；其实地上本没有路，走的人多了，也便成了路。
'''{text}'''
"""
response=get_completion(prompt)
display(Markdown(response))
# Out:
# **文章一**
# 荒原中的独喊，无人应答，唯有悲哀。这寂静让我看清自己，非振臂高呼的英雄，只是孤独的行者。
#
# **文章二**
# 希望有无，如地上的路。本无路，走的人多了，便成了路。行动是光，照亮前行的方向。

# %%
text=f"""
写两篇文章，100字以内
"""
prompt=f"""
'''{text}'''
"""
response=get_completion(prompt)
display(Markdown(response))
# Out:
# **文章一**
# 晨光微熹，露珠在叶尖滚动，折射出七彩光芒。鸟鸣清脆，唤醒沉睡的街道。新的一天，带着希望与温暖，轻轻开启。
#
# **文章二**
# 夜幕降临，星辰点缀天幕，晚风轻拂脸庞。灯火阑珊，城市渐入宁静。此刻，心绪如水，在静谧中沉淀，与夜色相拥。
