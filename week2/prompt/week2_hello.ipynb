# %% [markdown]
# 调用api

# %%
import os
from dotenv import load_dotenv
from zhipuai import ZhipuAI
import textwrap

# %%
load_dotenv("api.env")

#初始化客户端
client=ZhipuAI(api_key=os.getenv('ZHIPUAI_API_KEY'))

# %%
#创建对话
response=client.chat.completions.create(
    model='glm-4',
    messages=[
        {"role":"user","content":"介绍一下你自己，用JSON格式输出。"}
    ])
ai_reply=response.choices[0].message.content
formatted_text=textwrap.fill(ai_reply)

print(f"{formatted_text}")
# Out:
# ```json {   "name": "GLM",   "type": "大语言模型",   "developer": "智谱AI",
# "version": "持续迭代更新中",   "description": "我是一个由智谱AI训练的大语言模型，旨在通过自然语言处理技术
# 为用户提供信息查询、问题解答、创意生成等多种服务。我能够理解和生成人类语言，帮助用户完成各类文本相关的任务。",
# "capabilities": [     "回答各类问题",     "提供信息检索",     "生成创意文本",
# "辅助学习与写作",     "语言翻译",     "代码生成与解释"   ],   "limitations": [
# "知识截止于训练数据",     "无法访问实时互联网信息",     "对复杂推理任务可能存在局限",     "生成内容需用户自行验证"
# ],   "interaction_style": "友好、专业、乐于助人",   "goal":
# "通过自然语言处理技术，为用户提供准确、有用的信息和服务，助力用户解决问题、提升效率。" } ```

# %%
client=ZhipuAI(api_key=os.getenv('ZHIPUAI_API_KEY'))

response=client.chat.completions.create(
    model='glm-4',
    messages=[
        {"role":"user","content":"我该怎么在这段代码里加提示词工程？"}
    ]
)
print(response.choices[0].message.content)
# Out:
# 太棒了！这是一个非常核心且重要的问题。将“提示词工程”融入代码，意味着你不再是在硬编码指令，而是**将提示词作为一种可配置、可优化、可复用的“代码资产”**来管理。
#
# 下面我将从**核心思想、具体方法、代码示例**三个层面，为你详细拆解如何在这段代码里加入提示词工程。
#
# ---
#
# ### 一、 核心思想：从“硬编码”到“工程化”
#
# 首先，我们要转变一个观念：
#
# | 传统方式（硬编码） | 提示词工程方式（工程化） |
# | :--- | :--- |
# | 提示词直接写在代码里，像字符串一样。 | 提示词被提取出来，存储在外部文件或配置中。 |
# | 修改提示词需要改动代码，重新部署。 | 修改提示词只需修改配置文件，无需重新部署代码。 |
# | 提示词是静态的，无法在运行时动态调整。 | 提示词可以是动态的，根据输入、用户角色等实时生成。 |
# | 提示词是“一次性”的，难以复用和版本管理。 | 提示词可以作为模块，被不同功能复用，并支持版本管理。 |
# | 难以进行A/B测试，不知道哪个提示词效果更好。 | 可以轻松实现A/B测试，对比不同提示词的效果。 |
#
# **一句话总结：把你的提示词想象成API的请求体或数据库的配置项，而不是代码里的一个普通字符串。**
#
# ---
#
# ### 二、 具体方法与最佳实践
#
# 假设你的原始代码是这样的（这是一个简单的Python调用OpenAI API的例子）：
#
# ```python
# # --- 你的原始代码（示例） ---
# import openai
#
# def generate_story(topic):
#     response = openai.ChatCompletion.create(
#         model="gpt-4",
#         messages=[
#             {"role": "system", "content": "你是一个专业的科幻小说家。"},
#             {"role": "user", "content": f"请根据主题 '{topic}' 写一个100字的故事。"}
#         ]
#     )
#     return response.choices[0].message['content']
#
# # 调用
# print(generate_story("一个会飞的鱼"))
# ```
#
# 现在，我们用提示词工程的思想来改造它。
#
# #### 方法一：提示词外部化（最基础也是最关键的一步）
#
# 将提示词从代码中剥离，存放到外部文件中，如JSON、YAML或纯文本文件。
#
# **1. 创建提示词配置文件 (e.g., `prompts.json`)**
#
# ```json
# {
#   "system_role": "你是一个专业的科幻小说家。",
#   "story_task_template": "请根据主题 '{topic}' 写一个100字的故事。"
# }
# ```
#
# 或者使用YAML (`prompts.yaml`)，它更易读：
#
# ```yaml
# system_role: "你是一个专业的科幻小说家。"
# story_task_template: "请根据主题 '{topic}' 写一个100字的故事。"
# ```
#
# **2. 修改你的代码，从文件中加载提示词**
#
# ```python
# import openai
# import json # 或者使用 PyYAML
#
# # 从JSON文件加载提示词
# with open('prompts.json', 'r', encoding='utf-8') as f:
#     prompts_config = json.load(f)
#
# def generate_story(topic):
#     # 使用配置文件中的模板，并填充动态参数
#     user_prompt = prompts_config['story_task_template'].format(topic=topic)
#
#     response = openai.ChatCompletion.create(
#         model="gpt-4",
#         messages=[
#             {"role": "system", "content": prompts_config['system_role']},
#             {"role": "user", "content": user_prompt}
#         ]
#     )
#     return response.choices[0].message['content']
#
# print(generate_story("一个会飞的鱼"))
# ```
#
# **好处：**
# *   **解耦：** 逻辑代码和提示词内容分离。
# *   **可维护性：** 产品经理或运营人员可以修改`prompts.json`来调整输出风格，无需接触代码。
# *   **可读性：** 提示词内容更清晰，易于阅读和管理。
#
# ---
#
# #### 方法二：使用模板引擎（处理动态参数）
#
# 当提示词需要根据输入动态变化时（比如上文中的`{topic}`），简单的`format()`可能不够用。这时可以使用专门的模板引擎，如Jinja2。
#
# **1. 安装Jinja2**
# `pip install Jinja2`
#
# **2. 创建提示词模板文件 (e.g., `story_template.jinja2`)**
#
# ```jinja
# 你是一个专业的科幻小说家。
# {% if style %}
# 你的写作风格必须是 {{ style }}。
# {% endif %}
#
# 请根据主题 '{{ topic }}' 写一个{{ length }}字的故事。
# ```
#
# **3. 修改代码，使用Jinja2渲染模板**
#
# ```python
# import openai
# from jinja2 import Environment, FileSystemLoader
#
# # 设置Jinja2环境
# env = Environment(loader=FileSystemLoader('.'))
# template = env.get_template('story_template.jinja2')
#
# def generate_story(topic, length=100, style=None):
#     # 使用模板渲染，传入所有变量
#     prompt_content = template.render(
#         topic=topic,
#         length=length,
#         style=style
#     )
#
#     response = openai.ChatCompletion.create(
#         model="gpt-4",
#         messages=[
#             {"role": "system", "content": "你是一个专业的科幻小说家。"}, # 系统角色可以也模板化
#             {"role": "user", "content": prompt_content}
#         ]
#     )
#     return response.choices[0].message['content']
#
# # 调用，可以动态传入参数
# print("--- 默认风格 ---")
# print(generate_story("一个会飞的鱼"))
#
# print("\n--- 指定风格 ---")
# print(generate_story("一个会飞的鱼", style="宫崎骏动画风格", length=150))
# ```
#
# **好处：**
# *   **强大的动态能力：** 可以处理复杂的条件逻辑（`if/else`）、循环、变量等。
# *   **结构化：** 让提示词的结构更清晰，逻辑更严谨。
# *   **可复用性高：** 一个模板可以生成成千上万种不同的提示词。
#
# ---
#
# #### 方法三：模块化与复用（构建提示词库）
#
# 将不同功能的提示词组织成模块，避免重复代码。
#
# **1. 创建提示词模块目录结构**
#
# ```
# /prompt_module
# ├── __init__.py
# ├── story.py      # 故事相关的提示词
# ├── summarizer.py # 摘要相关的提示词
# └── utils.py      # 通用工具函数
# ```
#
# **2. 在 `story.py` 中定义提示词**
#
# ```python
# # /prompt_module/story.py
# from jinja2 import Environment, FileSystemLoader
# import os
#
# # 获取当前文件所在目录
# current_dir = os.path.dirname(os.path.abspath(__file__))
# env = Environment(loader=FileSystemLoader(current_dir))
#
# # 定义系统角色
# SYSTEM_ROLE = "你是一个专业的科幻小说家。"
#
# # 定义任务模板
# STORY_TEMPLATE = """
# 你是一个专业的科幻小说家。
# {% if style %}
# 你的写作风格必须是 {{ style }}。
# {% endif %}
#
# 请根据主题 '{{ topic }}' 写一个{{ length }}字的故事。
# """
#
# def get_story_prompt(topic, length=100, style=None):
#     """生成故事任务的提示词"""
#     template = env.from_string(STORY_TEMPLATE)
#     user_content = template.render(topic=topic, length=length, style=style)
#
#     # 返回符合OpenAI API格式的消息列表
#     return [
#         {"role": "system", "content": SYSTEM_ROLE},
#         {"role": "user", "content": user_content}
#     ]
# ```
#
# **3. 在你的主代码中调用模块**
#
# ```python
# import openai
# from prompt_module.story import get_story_prompt
#
# def generate_story_api(topic, length=100, style=None):
#     # 直接调用模块获取提示词列表
#     messages = get_story_prompt(topic, length, style)
#
#     response = openai.ChatCompletion.create(
#         model="gpt-4",
#         messages=messages
#     )
#     return response.choices[0].message['content']
#
# # 调用
# print(generate_story_api("一个会飞的鱼", style="赛博朋克"))
# ```
#
# **好处：**
# *   **高内聚低耦合：** 每个模块只负责自己的提示词，职责清晰。
# *   **易于管理：** 所有提示词都集中在特定目录下，方便查找和更新。
# *   **易于测试：** 可以单独测试每个提示词模块的正确性。
#
# ---
#
# #### 方法四：实现提示词的A/B测试（数据驱动优化）
#
# 想知道哪个提示词效果更好？用A/B测试！
#
# **1. 创建多个版本的提示词配置**
#
# ```json
# // prompts_v1.json (旧版本)
# {
#   "system_role": "你是一个专业的科幻小说家。",
#   "story_task_template": "请根据主题 '{topic}' 写一个100字的故事。"
# }
#
# // prompts_v2.json (新版本，尝试更具体的指令)
# {
#   "system_role": "你是一个顶级的科幻小说家，擅长创造富有想象力的世界。",
#   "story_task_template": "请根据主题 '{topic}'，创作一个情节紧凑、充满悬念的100字短篇故事。"
# }
# ```
#
# **2. 修改代码，加入随机选择逻辑**
#
# ```python
# import openai
# import json
# import random
#
# def load_prompt_config(version):
#     with open(f'prompts_v{version}.json', 'r', encoding='utf-8') as f:
#         return json.load(f)
#
# def generate_story_with_ab_test(topic):
#     # 随机选择一个版本 (50%概率选v1或v2)
#     version = random.choice([1, 2])
#     prompts_config = load_prompt_config(version)
#
#     print(f"--- 当前使用的是版本 {version} 的提示词 ---")
#
#     user_prompt = prompts_config['story_task_template'].format(topic=topic)
#
#     response = openai.ChatCompletion.create(
#         model="gpt-4",
#         messages=[
#             {"role": "system", "content": prompts_config['system_role']},
#             {"role": "user", "content": user_prompt}
#         ]
#     )
#     return response.choices[0].message['content']
#
# # 调用几次，观察输出差异
# print(generate_story_with_ab_test("一个会飞的鱼"))
# print(generate_story_with_ab_test("一个会飞的鱼"))
# ```
#
# **进阶做法：**
# *   **日志记录：** 每次调用时，记录下使用的版本号、输入和输出，存入数据库。
# *   **数据分析：** 定期分析日志，对比不同版本在用户满意度、任务完成率等指标上的表现，从而确定最优版本。
#
# ---
#
# ### 总结与建议
#
# 1.  **从第一步开始：** 无论你的项目多小，**第一步永远是“提示词外部化”**。这会让你立刻感受到工程化带来的好处。
# 2.  **按需选择：** 如果你的提示词很简单，用`format()`和JSON/YAML就够了。如果逻辑复杂，再引入Jinja2。
# 3.  **逐步构建：** 不要试图一次性做完所有步骤。从一个简单的配置文件开始，随着项目复杂度的增加，再逐步引入模板引擎和模块化。
# 4.  **拥抱变化：** 提示词工程的核心思想是**“提示词是活的，需要不断迭代优化”**。一个好的工程化架构能让你轻松应对这种变化。
#
# 通过以上方法，你就能将一段简单的代码，升级为一个健壮、灵活、可维护的提示词应用系统。这不仅能提升你的开发效率，更能让你在AI应用的开发中走得更远、更稳。

# %% [markdown]
# AI
