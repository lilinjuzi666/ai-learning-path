# %%
import os # 导入os模块以访问环境变量
from client import get_completion # 导入get_completion函数以获取AI的响应
from IPython.display import display,Markdown # 导入display和Markdown函数以显示格式化的文本

# %%
text = f"""
讲解一下ai应用开发
"""
prompt = f"""
你是一名ai架构师，有着丰富的ai应用开发经验
'''{text}'''
"""
response = get_completion(prompt)
display(Markdown(response))
# Out:
# 好的，各位同仁，大家好。
#
# 作为一名在AI应用开发领域摸爬滚打了多年的架构师，我非常乐意和大家分享我的经验和见解。AI应用开发早已不是几年前的“炼丹”时代，它已经演变成一门严谨、系统化的工程学科。今天，我将从一个架构师的视角，系统地为大家拆解AI应用开发的整个生命周期。
#
# ---
#
# ### **AI应用开发：从“炼丹”到“系统工程”的演进**
#
# 首先，我们要明确一个核心观点：**一个成功的AI应用，绝不仅仅是模型本身，而是“数据 + 算法 + 工程”三位一体的有机结合体。** 模型是大脑，数据是燃料，而工程则是骨架和神经系统，负责将大脑的智能决策高效、可靠、可扩展地传递到业务场景中。
#
# 下面，我将AI应用开发的生命周期分为六个关键阶段，并结合架构师的视角进行讲解。
#
# ---
#
# ### **第一阶段：问题定义与价值验证**
#
# 这是整个项目最关键，也最容易被忽视的一步。很多项目失败，不是因为技术不行，而是从一开始就错了。
#
# **做什么？**
# 1.  **业务问题抽象化：** 将模糊的业务需求（比如“我想提升用户活跃度”）转化为一个或多个可量化、可解决的AI问题（比如“预测用户在未来7天内流失的概率，并识别高流失风险用户进行精准干预”）。
# 2.  **可行性评估：**
#     *   **数据可行性：** 我们是否有足够的历史数据来训练模型？数据的质量如何？是否存在数据孤岛？
#     *   **技术可行性：** 现有技术能否解决该问题？是简单的分类/回归问题，还是复杂的NLP/CV任务？
#     *   **价值评估：** 解决这个问题能带来多大的商业价值？投入产出比如何？这决定了项目的优先级和资源投入。
# 3.  **设定成功标准：** 定义清晰的评估指标。例如，模型的AUC需要达到0.85，上线后用户流失率需要降低10%。
#
# **架构师视角：**
# 在这一阶段，架构师需要扮演“业务翻译官”和“技术预言家”的角色。我们要与产品、业务方紧密合作，确保技术方案精准对齐商业目标。同时，要预判数据管道、算力资源、模型复杂度可能带来的挑战，为后续的技术选型提供早期输入。
#
# ---
#
# ### **第二阶段：数据工程**
#
# ...

# %%
text = f"""
讲解一下ai应用开发
"""
# prompt = f"""
# 你是一名ai架构师，有着丰富的ai应用开发经验
# '''{text}'''
# """
response = get_completion(text)
display(Markdown(response))
# Out:
# 好的，我们来系统地、由浅入深地讲解一下**AI应用开发**。
#
# 这不仅仅是写几行代码，而是一个结合了**业务理解、数据科学、软件工程和DevOps**的综合性过程。我会把它拆解成几个核心部分，让你能清晰地看到整个流程。
#
# ---
#
# ### **第一部分：AI应用开发是什么？**
#
# 简单来说，AI应用开发就是**利用人工智能技术（如机器学习、深度学习）来构建一个能够解决特定问题、创造商业价值的软件应用**。
#
# 与传统软件开发相比，它最大的不同在于**“智能”**。传统软件的流程是固定的（if-then-else），而AI应用的核心是一个**“模型”**，这个模型是从数据中学习出来的，能够进行预测、分类、生成等复杂任务。
#
# **一个生动的比喻：**
# *   **传统软件开发**：像教一个机器人做一道菜。你给它一份精确到克的食谱，它每次都会严格按照步骤执行，做出一模一样的菜。
# *   **AI应用开发**：像教一个学徒做菜。你给他看1000道菜的照片和做法（数据），让他自己总结出“什么是好吃的”、“盐放多少合适”、“如何根据现有食材创新”（模型）。之后，他不仅能复刻菜，还能根据你的口味（新输入）推荐或创造新菜。
#
# ---
#
# ### **第二部分：AI应用开发的核心流程**
#
# 一个完整的AI应用开发项目，通常遵循以下六个关键步骤。这是一个迭代循环的过程，而不是线性的。
#
# #### **步骤一：问题定义与业务理解**
#
# 这是**最重要**的一步，决定了项目的成败。在写任何代码之前，必须清晰地回答：
#
# *   **我们要解决什么问题？** (例如：是预测用户流失，还是识别图片中的垃圾邮件？)
# *   **这个问题是否适合用AI来解决？** (有些问题用规则引擎更简单高效。)
# *   **成功如何衡量？** (例如：预测准确率达到95%，推荐点击率提升20%。)
# *   **数据从哪里来？** 是否有足够、高质量的数据来训练模型？
#
# **产出物**：一份清晰的项目需求文档，包含业务目标、成功指标和数据来源。
#
# #### **步骤二：数据准备**
#
# AI的基石是数据。这一步通常占整个项目60%-80%的时间，包括：
#
# ...
