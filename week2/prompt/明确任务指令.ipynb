# %%
from client import get_completion
from IPython.display import display,Markdown

# %%
text=f"""
概括一下这篇文章:中新网3月12日电 据中央气象台网站消息，过去一天(3月11日)，冷空气开始影响新疆地区，新疆北部出现明显雨雪和大风降温天气，
乌鲁木齐、昌吉、塔城等局地降大雪或暴雪，伊犁河谷等地最高气温降温幅度超过12℃。
中央气象台预计，12日至15日，冷空气将继续东移南下给我国带来大范围雨雪、大风、降温和沙尘天气。期间，西南地区东部及黄淮以北大部地区气温将下降4～8℃，
西北地区的降温最为猛烈，部分地区降温幅度可达10～14℃，局地14℃以上；上述部分区域并伴有4～6级风，阵风7～8级。
其中12日，受大风天气影响，新疆东部和南部、内蒙古西部、甘肃西部、青海北部、宁夏中北部等地部分地区有扬沙或浮尘天气,
新疆南疆盆地东部、内蒙古西部、甘肃西部局地有沙尘暴或强沙尘暴。中央气象台12日早晨继续发布沙尘暴蓝色预警。
"""
prompt = f"""
100字以内
'''{text}'''
"""
response=get_completion(prompt)
display(Markdown(response))
# Out:
# 中央气象台消息，冷空气东移南下致我国大范围雨雪、大风、降温及沙尘天气，西北等地降温超14℃，新疆等地现沙尘暴，中央气象台发沙尘暴蓝色预警。

# %%
text=f"""
概括一下这篇文章:中新网3月12日电 据中央气象台网站消息，过去一天(3月11日)，冷空气开始影响新疆地区，新疆北部出现明显雨雪和大风降温天气，
乌鲁木齐、昌吉、塔城等局地降大雪或暴雪，伊犁河谷等地最高气温降温幅度超过12℃。
中央气象台预计，12日至15日，冷空气将继续东移南下给我国带来大范围雨雪、大风、降温和沙尘天气。期间，西南地区东部及黄淮以北大部地区气温将下降4～8℃，
西北地区的降温最为猛烈，部分地区降温幅度可达10～14℃，局地14℃以上；上述部分区域并伴有4～6级风，阵风7～8级。
其中12日，受大风天气影响，新疆东部和南部、内蒙古西部、甘肃西部、青海北部、宁夏中北部等地部分地区有扬沙或浮尘天气,
新疆南疆盆地东部、内蒙古西部、甘肃西部局地有沙尘暴或强沙尘暴。中央气象台12日早晨继续发布沙尘暴蓝色预警。
"""
prompt = f"""
'''{text}'''
"""
response=get_completion(prompt)
display(Markdown(response))
# Out:
# 好的，这篇文章可以概括为以下几点：
#
# **核心事件：**
# 一股强冷空气正在影响中国，并将在未来几天继续东移南下，带来大范围的恶劣天气。
#
# **主要影响：**
#
# 1.  **已发生（3月11日）：**
#     *   **地区：** 主要影响新疆北部。
#     *   **天气：** 出现明显雨雪、大风和剧烈降温。
#     *   **具体表现：** 乌鲁木齐等地有大雪或暴雪，伊犁河谷等地单日降温超过12℃。
#
# 2.  **预计影响（3月12日至15日）：**
#     *   **范围：** 大范围，覆盖西南地区东部及黄淮以北大部地区，其中西北地区降温最猛烈。
#     *   **降温：** 大部分地区气温下降4～8℃，西北部分地区降温可达10～14℃以上。
#     *   **大风与沙尘：** 新疆、内蒙古、甘肃等地将出现扬沙、浮尘，部分地区甚至有沙尘暴或强沙尘暴。中央气象台已为此发布沙尘暴蓝色预警。
#
# **一句话总结：**
# 一股强冷空气正自西向东影响中国，已导致新疆暴雪降温，未来几天将带来大范围雨雪、大风和剧烈降温，并可能引发西北地区的沙尘暴天气。
