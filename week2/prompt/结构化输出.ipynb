# %%
from client import get_completion
from IPython.display import display,Markdown

# %%
text=f"""提取姓名，电话号，身份证号
MEI
13283432555
13042500501030546
"""
prompt=f""""
以严格的标准JSON格式输出：
'''{text}'''
"""
response=get_completion(prompt)
display(Markdown(response))
# Out:
# ```json
# {
#   "姓名": "MEI",
#   "电话号": "13283432555",
#   "身份证号": "13042500501030546"
# }
# ```

# %%
text=f"""提取姓名，电话号，身份证号
MEI
13283432555
13042500501030546
"""
prompt=f""""
'''{text}'''
"""
response=get_completion(prompt)
display(Markdown(response))
# Out:
# 好的，根据您提供的文本，提取结果如下：
#
# *   **姓名:** MEI
# *   **电话号:** 13283432555
# *   **身份证号:** 13042500501030546
#
# ---
#
# ### **重要提醒：身份证号隐私**
#
# 您提供的身份证号 `13042500501030546` 是一个**示例号码**，因为它不符合国家规定的身份证号码校验规则（最后一位是校验码）。在实际应用中，请务必妥善保管真实的身份证号码，避免泄露个人隐私。
